# %%
import pandas as pd

data_texture = pd.read_excel("data_part_1.xls")
data_photo = pd.read_excel("data_part_2.xls")

data_texture_cols = data_1.columns
data_photo_cols = data_2.columns

data_texture_filter = data_1[[data_1_cols[0], data_1_cols[1], data_1_cols[17]]]
data_texture_filter.columns = ["name", "id", "color"]
data_texture_filter

data_photo_filter = data_2[[data_2_cols[0], data_2_cols[1], data_2_cols[17]]]
data_photo_filter.columns = ["name", "id", "color"]
data_photo_filter

goal = 90060490
name = None
color = None
for idx, item in enumerate(data_texture_filter["id"].values):
    if goal == item:
        name = data_texture_filter["name"][idx]
        color = data_texture_filter["color"][idx]
        
print(goal, name, color)
# Out:
# 90060490 обои ANKA  ADA WALL коричневый

# %%
data_texture_filter
# Out:
#                                                name        id       color
# 0                                 обои вин "Bricko"  90001906     красный
# 1                                 обои вин "Bricko"  90001905  коричневый
# 2                                 обои вин "Bricko"  90001902  коричневый
# 3                   обои всп вин на флиз ос "Свирл"  90001597     зелёный
# 4                                 обои вин "Bricko"  90001903  коричневый
# 5                   обои всп вин на флиз ос "Свирл"  90001594  коричневый
# 6                   обои всп вин на флиз ос "Свирл"  90001596     красный
# 7                   обои всп вин на флиз ос "Свирл"  90001595     бежевый
# 8                                 обои вин "Bricko"  90001904       серый
# 9                   обои всп вин на флиз ос "Свирл"  90001593      чёрный
# 10              обои всп вин на флиз ос "Structure"  90001638       серый
# 11                  обои всп вин на флиз ос "Оникс"  90001650       серый
# ...
